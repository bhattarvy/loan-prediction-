# %%
import pandas as pd
import numpy as np
import matplotlib.pyplot as plt
from sklearn.preprocessing import StandardScaler

data=pd.read_csv('/home/arvy/Documents/ML/datasets/train_u6lujuX_CVtuZ9i.csv')
data.drop(['Loan_ID'],axis=1,inplace =True)

# %%
from sklearn.preprocessing import Binarizer


data.head(50)

for x in range(0,data.Dependents.shape[0]):
    if data.Dependents[x] == '3+':
        data.Dependents[x]='3'

data.head(30)
# Out:
#     Gender Married Dependents     Education Self_Employed  ApplicantIncome  \
# 0     Male      No          0      Graduate            No             5849
# 1     Male     Yes          1      Graduate            No             4583
# 2     Male     Yes          0      Graduate           Yes             3000
# 3     Male     Yes          0  Not Graduate            No             2583
# 4     Male      No          0      Graduate            No             6000
# 5     Male     Yes          2      Graduate           Yes             5417
# 6     Male     Yes          0  Not Graduate            No             2333
# 7     Male     Yes          3      Graduate            No             3036
# 8     Male     Yes          2      Graduate            No             4006
# 9     Male     Yes          1      Graduate            No            12841
# 10    Male     Yes          2      Graduate            No             3200
# ...

# %%
from sklearn.preprocessing import LabelEncoder
gle=LabelEncoder()
data.Gender=gle.fit_transform(data['Gender'])
data.Married=gle.fit_transform(data['Married'])
data.Education=gle.fit_transform(data['Education'])
data.Self_Employed=gle.fit_transform(data.Self_Employed)
data.Property_Area=gle.fit_transform(data.Property_Area)
data.Loan_Status=gle.fit_transform(data.Loan_Status)
print(data.head(50))
data.info()
data.fillna(0)

from sklearn.preprocessing import StandardScaler
scal=StandardScaler()
scal.fit_transform(data)


data.Dependents.fillna('0',inplace=True)
data.Dependents.astype(int)

print(data.head(50))
# Out:
#     Gender  Married Dependents  Education  Self_Employed  ApplicantIncome  \
# 0        2        1          0          0              1             5849
# 1        2        2          1          0              1             4583
# 2        2        2          0          0              2             3000
# 3        2        2          0          1              1             2583
# 4        2        1          0          0              1             6000
# 5        2        2          2          0              2             5417
# 6        2        2          0          1              1             2333
# 7        2        2          3          0              1             3036
# 8        2        2          2          0              1             4006
# 9        2        2          1          0              1            12841
# 10       2        2          2          0              1             3200
# 11       2        2          2          0              0             2500
# ...

# %%
data.fillna(0)
data.corr(method='pearson')['Loan_Status']
# Out:
# ---------------------------------------------------------------------------
# AttributeError                            Traceback (most recent call last)
# <ipython-input-135-3fc05b0491bf> in <module>()
#       2 data.corr(method='pearson')['Loan_Status']
#       3
# ----> 4 data.corr.hist()
#
# AttributeError: 'function' object has no attribute 'hist'

# %%
y=data.Loan_Status
X=data.drop(['Loan_Status'],axis=1)
from sklearn.cross_validation import train_test_split
X_train, X_test, y_train, y_test = train_test_split( X, y, test_size=0.20, random_state=42)

# %%
from sklearn.svm import SVC
model=SVC()
model.fit(X_train,y_train)
# Out:
# ---------------------------------------------------------------------------
# ValueError                                Traceback (most recent call last)
# <ipython-input-141-57a7bd0f9ea4> in <module>()
#       1 from sklearn.svm import SVC
#       2 model=SVC()
# ----> 3 model.fit(X_train,y_train)
#
# /home/arvy/anaconda/lib/python2.7/site-packages/sklearn/svm/base.pyc in fit(self, X, y, sample_weight)
#     147         self._sparse = sparse and not callable(self.kernel)
#     148
# --> 149         X, y = check_X_y(X, y, dtype=np.float64, order='C', accept_sparse='csr')
#     150         y = self._validate_targets(y)
#     151
#
# /home/arvy/anaconda/lib/python2.7/site-packages/sklearn/utils/validation.pyc in check_X_y(X, y, accept_sparse, dtype, order, copy, force_all_finite, ensure_2d, allow_nd, multi_output, ensure_min_samples, ensure_min_features, y_numeric, warn_on_dtype, estimator)
#     571     X = check_array(X, accept_sparse, dtype, order, copy, force_all_finite,
# ...
